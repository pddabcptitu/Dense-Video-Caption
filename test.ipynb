# %%
import open_clip

model, _ = open_clip.create_model_from_pretrained('ViT-L-14', pretrained='openai')

# %%
import torch
import PIL.Image as Image

img = Image.open(r'C:\PDD\Dense Video Caption\Screenshot 2026-03-14 163317.png')
img_tens = proccess(img).unsqueeze(0)
feat = model.encode_image(img_tens)
feat.shape

# %%
# %load_ext autoreload
# %autoreload 2

import extract.utils.get_frames as get_frames

# %%
t = get_frames.get_frames(r'C:\PDD\Dense Video Caption\video (2).mp4', 1)
t.shape

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained(
    "VietAI/vit5-base"
)

model = T5ForConditionalGeneration.from_pretrained(
    "VietAI/vit5-base"
)

print("OK")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 from transformers import T5Tokenizer, T5ForConditionalGeneration
# ----> 3 tokenizer = T5Tokenizer.from_pretrained(
#       4     "VietAI/vit5-base"
#       5 )
#       7 model = T5ForConditionalGeneration.from_pretrained(
#       8     "VietAI/vit5-base"
#       9 )
#      11 print("OK")
#
# File c:\PDD\Dense Video Caption\.venv310\lib\site-packages\transformers\tokenization_utils_base.py:1721, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    1718     if file_id not in resolved_vocab_files:
#    1719         continue
# -> 1721 return cls._from_pretrained(
#    1722     resolved_vocab_files,
#    1723     pretrained_model_name_or_path,
#    1724     init_configuration,
#    1725     *init_inputs,
#    1726     token=token,
#    1727     cache_dir=cache_dir,
#    1728     local_files_only=local_files_only,
#    1729     _commit_hash=commit_hash,
#    1730     _is_local=is_local,
#    1731     trust_remote_code=trust_remote_code,
#    1732     **kwargs,
#    1733 )
#
# File c:\PDD\Dense Video Caption\.venv310\lib\site-packages\transformers\tokenization_utils_base.py:1907, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    1901         init_kwargs[key] = added_tokens_map.get(str(init_kwargs[key]), init_kwargs[key])
#    1903 # From pretrained with the legacy fixes
#    1904 # for `tokenizers` based tokenizer, we actually want to have vocab and merges pre-extracted from whatever inputs
#    1905 # for `none` (PythonBackend) based tokenizer, we also want the vocab file / merge files not extracted.
#    1906 # for `sentencepiece` based tokenizer, we pass the sentencepiece model file directly.
# -> 1907 init_kwargs = cls.convert_to_native_format(**init_kwargs)
#    1909 try:
#    1910     tokenizer = cls(*init_inputs, **init_kwargs)
#
# File c:\PDD\Dense Video Caption\.venv310\lib\site-packages\transformers\tokenization_utils_tokenizers.py:158, in TokenizersBackend.convert_to_native_format(cls, trust_remote_code, **kwargs)
#     156         vocab = list(map(tuple, vocab))  # TODO just for now
#     157 elif cls.model.__name__ == "Unigram":
# --> 158     if vocab and isinstance(vocab[0], (list, tuple)):
#     159         vocab = [tuple(item) for item in vocab]
#     160 elif cls.model.__name__ == "WordLevel":
#
# KeyError: 0
